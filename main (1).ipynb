# %%
import os

# %% [markdown]
# # Import function from their own folders

# %%
#find current path file 
start_path = os.getcwd()

# %%
#add A1 to path file
A1_path = start_path + '\A1'
#change pathfile to A1
os.chdir(A1_path)

# %%
# import final model from A1.ipynb
from ipynb.fs.defs.A1 import A1

# %%
# add A2 folder to the main path file 
A2_path = start_path + '\A2'
#change to path file of A2 folder 
os.chdir(A2_path)

# %%
# import final model from A2.ipynb
from ipynb.fs.defs.A2 import A2

# %%
# add B1 to main path file 
B1_path = start_path + '\B1'
#chnage to pathfile of B1 folder 
os.chdir(B1_path)

# %%
# import final model from B1.ipynb
from ipynb.fs.defs.B1 import B1

# %%
# add B2 to main file path
B2_path = start_path + '\B2'
# change path file to B2 folder 
os.chdir(B2_path)

# %%
# import final model from B2.ipynb
from ipynb.fs.defs.B2 import B2

# %%
# change back to main file path file. 
os.chdir(start_path)

# %% [markdown]
# # Test A1: Classifing by Gender

# %%
A1()
# Out:
# The optimised model used for A1 is: LogisticRegression(C=0.01)
# C:\Users\Student\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# The model accuracy for A1 is: 90.7 %

# %% [markdown]
# # Test A2: Classifying by smiling

# %%
A2()
# Out:
# The optimised model used for A2 is RandomForestClassifier(max_depth=90, min_samples_leaf=5, min_samples_split=8,
#                        n_estimators=300)
# The accuracy for A2 is: 87.4 %

# %% [markdown]
# # Test B1: Classifying by face shape

# %%
B1()
# Out:
# C:\Users\Student\anaconda3\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# The optimised model used for B1 is: LinearSVC(C=1)
# The accuracy of the optimised model for B1 is: 99.88 %

# %% [markdown]
# # Test B2: Classifying by eye colour

# %%
B2()
# Out:
# 1612 images containing sunglasses were removed from the training dataset
# 410 number of images containing sunglasses were removed from the testing dataset
# C:\Users\Student\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# The optimised model used for B2 is LogisticRegression(C=0.01)
# This is the accuracy for B2 96.1244019138756 %

# %% [markdown]
# # Run the complete file

# %%
#Run all A1
# %run A1/A1.ipynb
# Out:
# The optimised model used for A1 is: LogisticRegression(C=0.01)
# C:\Users\Student\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# The model accuracy for A1 is: 91.3 %
# C:\Users\Student\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
#Run all A2
# %run A2/A2.ipynb
# Out:
# The optimised model used for A2 is RandomForestClassifier(max_depth=90, min_samples_leaf=5, min_samples_split=8,
#                        n_estimators=300)
# The accuracy for A2 is: 87.2 %
# Fitting 3 folds for each of 1875 candidates, totalling 5625 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed: 43.0min
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed: 62.0min
# [Parallel(n_jobs=-1)]: Done 1977 tasks      | elapsed: 81.3min
# [Parallel(n_jobs=-1)]: Done 2584 tasks      | elapsed: 119.8min
# [Parallel(n_jobs=-1)]: Done 3273 tasks      | elapsed: 161.2min
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed: 181.4min
# ...

# %%
#Run all B1
# %run B1/B1.ipynb
# Out:
# C:\Users\Student\anaconda3\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# The optimised model used for B1 is: LinearSVC(C=1)
# The accuracy of the optimised model for B1 is: 99.96000000000001 %
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed: 13.6min finished
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed: 13.6min remaining:    0.0s
# C:\Users\Student\anaconda3\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Student\anaconda3\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
# ...

# %%
#Run all B2
# %run B2/B2.ipynb
# Out:
# 1612 images containing sunglasses were removed from the training dataset
# 410 number of images containing sunglasses were removed from the testing dataset
# C:\Users\Student\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# The optimised model used for B2 is LogisticRegression(C=0.01)
# This is the accuracy for B2 96.3157894736842 %
# 1612 images containing sunglasses were removed from the training dataset
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# ...
